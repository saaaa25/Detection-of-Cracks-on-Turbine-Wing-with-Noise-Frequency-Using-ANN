# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
data = pd.read_csv("dataset.csv")
data = data.drop(['Index'], axis =1)
data.head()
# Out:
#     L1    D1    W1   L2    D2    W2   A2        M1        M2         M3  ...  \
# 0   56  4.87  0.45  506  0.44  0.25   23  15.90109  81.14046  102.24640  ...
# 1   65  7.18  0.35  271  5.37  0.25   47  13.50639  76.61076   94.36555  ...
# 2  248  5.51  0.50  361  1.46  0.10  328  16.23756  81.97516  102.06620  ...
# 3  371  6.77  0.45  393  4.12  0.15  359  16.32675  82.31082   93.28761  ...
# 4  386  5.25  0.35  423  6.09  0.40   16  16.47852  82.52456   94.90102  ...
#
#          M6        M7        M8        M9       M10       M11       M12  \
# 0  503.0457  571.4751  943.9522  1244.580  1369.678  1401.007  1762.824
# 1  488.0853  567.9029  898.5086  1238.621  1330.465  1353.272  1530.789
# 2  502.7974  571.1062  910.5368  1252.036  1356.001  1364.529  1758.666
# 3  486.6037  528.5412  924.8589  1238.695  1323.581  1367.612  1733.544
# 4  487.7985  553.8937  888.0914  1234.283  1349.795  1375.997  1735.958
#
#         M13       M14       M15
# 0  1943.602  2086.309  2558.577
# 1  1906.431  2058.947  2469.460
# 2  1957.347  2081.241  2510.664
# 3  1917.711  2087.172  2501.153
# 4  1896.219  2093.194  2487.739
#
# [5 rows x 22 columns]

# %%
data.isnull().sum()
# Out:
# L1      0
# D1      0
# W1      0
# L2      0
# D2      0
# W2      0
# A2      0
# M1     33
# M2     33
# M3     33
# M4     33
# M5     33
# M6     33
# M7     33
# M8     33
# M9     33
# M10    33
# M11    33
# M12    33
# M13    33
# M14    33
# M15    33
# dtype: int64

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# L1     0
# D1     0
# W1     0
# L2     0
# D2     0
# W2     0
# A2     0
# M1     0
# M2     0
# M3     0
# M4     0
# M5     0
# M6     0
# M7     0
# M8     0
# M9     0
# M10    0
# M11    0
# M12    0
# M13    0
# M14    0
# M15    0
# dtype: int64

# %%
X = data.iloc[:,7:]
Y = data.iloc[:,0:7]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
Y1_train = Y_train.iloc[:,0]
Y2_train = Y_train.iloc[:,1]
Y3_train = Y_train.iloc[:,2]
Y4_train = Y_train.iloc[:,3]
Y5_train = Y_train.iloc[:,4]
Y6_train = Y_train.iloc[:,5]
Y7_train = Y_train.iloc[:,6]

Y1_test = Y_test.iloc[:,0]
Y2_test = Y_test.iloc[:,1]
Y3_test = Y_test.iloc[:,2]
Y4_test = Y_test.iloc[:,3]
Y5_test = Y_test.iloc[:,4]
Y6_test = Y_test.iloc[:,5]
Y7_test = Y_test.iloc[:,6]

# %% [markdown]
# # Suport Vector Machine - Regression
#
# An instructional algorithm built with VC theory as its bedrock. This learning technique attempts to maximize margins over the hypersurface while fitting a hyperspace onto the input. Despite the model's linearity, we are able to introduce non-linearity by employing the kernel method. When applying a kernel function to the data domain in a high-dimensional feature space, at least one linear hypersurface is guaranteed to be preserved in the resulting domain. When the data are retransformed back into their original domain, the non-linearity of the model is restored.

# %%
X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)

# %%
from sklearn.preprocessing import StandardScaler
def scale_datasets(x_train, x_test):
  """
  Standard Scale test and train data
  Z - Score normalization
  """
  standard_scaler = StandardScaler()
  x_train_scaled = pd.DataFrame(
      standard_scaler.fit_transform(x_train),
      columns=x_train.columns
  )
  x_test_scaled = pd.DataFrame(
      standard_scaler.transform(x_test),
      columns = x_test.columns
  )
  return x_train_scaled, x_test_scaled
x_train_scaled, x_test_scaled = scale_datasets(X_train, X_test)

# %%
# train the model
model1 = SVR()
model1.fit(x_train_scaled, Y1_train)
ypred1 = model1.predict(x_test_scaled)
X_test['L1_prediction'] = ypred1

print("Mean Squared Error : ", mean_squared_error(Y1_test, ypred1))
print("Mean Absolute Error : ", mean_absolute_error(Y1_test, ypred1))
# Out:
# Mean Squared Error :  19260.70793703918
# Mean Absolute Error :  108.52791987525221

# %%
model2 = SVR()
model2.fit(x_train_scaled, Y2_train)
ypred2 = model2.predict(x_test_scaled)
X_test['D1_prediction'] = ypred2

print("Mean Squared Error : ", mean_squared_error(Y2_test, ypred2))
print("Mean Absolute Error : ", mean_absolute_error(Y2_test, ypred2))
# Out:
# Mean Squared Error :  2.2639813234936907
# Mean Absolute Error :  0.9532645882250117

# %%
model3 = SVR()
model3.fit(x_train_scaled, Y3_train)
ypred3 = model3.predict(x_test_scaled)
X_test['W1_prediction'] = ypred3

print("Mean Squared Error : ", mean_squared_error(Y3_test, ypred3))
print("Mean Absolute Error : ", mean_absolute_error(Y3_test, ypred3))
# Out:
# Mean Squared Error :  0.018923022977382443
# Mean Absolute Error :  0.11964883731472008

# %%
# train the model
model4 = SVR()
model4.fit(x_train_scaled, Y4_train)
ypred4 = model4.predict(x_test_scaled)
X_test['L2_prediction'] = ypred4

print("Mean Squared Error : ", mean_squared_error(Y4_test, ypred4))
print("Mean Absolute Error : ", mean_absolute_error(Y4_test, ypred4))
# Out:
# Mean Squared Error :  23273.70765687775
# Mean Absolute Error :  122.0728116044439

# %%
# train the model
model5 = SVR()
model5.fit(x_train_scaled, Y5_train)
ypred5 = model5.predict(x_test_scaled)
X_test['D2_prediction'] = ypred5

print("Mean Squared Error : ", mean_squared_error(Y5_test, ypred5))
print("Mean Absolute Error : ", mean_absolute_error(Y5_test, ypred5))
# Out:
# Mean Squared Error :  2.002455779049096
# Mean Absolute Error :  0.961955239147221

# %%
# train the model
model6 = SVR()
model6.fit(x_train_scaled, Y6_train)
ypred6 = model6.predict(x_test_scaled)
X_test['W2_prediction'] = ypred6

print("Mean Squared Error : ", mean_squared_error(Y6_test, ypred6))
print("Mean Absolute Error : ", mean_absolute_error(Y6_test, ypred6))
# Out:
# Mean Squared Error :  0.0184680886297512
# Mean Absolute Error :  0.11681881942469391

# %%
# train the model
model7 = SVR()
model7.fit(x_train_scaled, Y7_train)
ypred7 = model7.predict(x_test_scaled)
X_test['A2_prediction'] = ypred7

print("Mean Squared Error : ", mean_squared_error(Y7_test, ypred7))
print("Mean Absolute Error : ", mean_absolute_error(Y7_test, ypred7))
# Out:
# Mean Squared Error :  36511.71614744683
# Mean Absolute Error :  152.74283349657338
